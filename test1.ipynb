# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DataScience QA.csv")

# %%
df.sample(8)
# Out:
#                                               Question  \
# 129     What is exploration in reinforcement learning?
# 89                      What is the Apriori algorithm?
# 100        What is the purpose of generative modeling?
# 121        What is an agent in reinforcement learning?
# 118  What is the Expectation-Maximization (EM) algo...
# 50   What is the purpose of the A/B test in data sc...
# 26   What are the main components of the data scien...
# 69     What is batch normalization in neural networks?
#
#                                                 Answer
# 129  Exploration is the process of actively seeking...
# 89   The Apriori algorithm is a classic algorithm f...
# 100  Generative modeling is used to model the under...
# 121  An agent is the entity that learns to make dec...
# 118  The Expectation-Maximization (EM) algorithm is...
# 50   A/B testing is a statistical hypothesis testin...
# 26   The main components include data collection, d...
# 69   Batch normalization is a technique used to nor...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Question  158 non-null    str
#  1   Answer    158 non-null    str
# dtypes: str(2)
# memory usage: 43.3 KB

# %%
df.shape
# Out:
# (158, 2)

# %%
df.isnull().sum()
# Out:
# Question    0
# Answer      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df.drop_duplicates(inplace=True)

# %%
import re
from nltk.corpus import stopwords

def clean_data(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z0-9]", ' ', text) # remove special characters
    text = re.sub(r"\s+", ' ', text) # remove extra spaces
    text = ' '.join([word for word in text.split() if word not in (stopwords.words('english'))])
    return text

# %%
df['Question'] = df['Question'].apply(clean_data)

# %%
df.sample(8)
# Out:
#                                               Question  \
# 149                                    policy learning
# 19                            self supervised learning
# 2     difference batch processing real time processing
# 90                                           fp growth
# 40                          explain difference pca sne
# 20                              reinforcement learning
# 54                          purpose hypothesis testing
# 131  exploration exploitation trade reinforcement l...
#
#                                                 Answer
# 149  On-policy learning is a learning method in rei...
# 19   Self-supervised learning is a form of unsuperv...
# 2    Batch processing involves processing data in l...
# 90   FP-Growth (Frequent Pattern Growth) is an effi...
# 40   PCA (Principal Component Analysis) is a linear...
# 20   Reinforcement learning is a type of machine le...
# 54   Hypothesis testing is used to make inferences ...
# 131  The exploration-exploitation trade-off refers ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_features=400)
X = vectorizer.fit_transform(df['Question'])
y = df['Answer']

# %%
X.shape
# Out:
# (146, 400)

# %%
y.shape
# Out:
# (146,)

# %%
df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
df['Answer'] = y
df.shape
# Out:
# (146, 401)

# %%
df.isnull().sum()
# Out:
# activation               0
# activation functions     0
# actor                    0
# actor critic             0
# advantage                0
#                         ..
# value                    0
# value decomposition      0
# value function           0
# variance                 0
# Answer                  12
# Length: 401, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df.shape
# Out:
# (134, 401)
